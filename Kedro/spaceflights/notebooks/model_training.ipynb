# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\drysd\anaconda3\envs\kedro\lib\site-packages (1.5.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\drysd\anaconda3\envs\kedro\lib\site-packages (from scikit-learn) (2.2.6)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\drysd\anaconda3\envs\kedro\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\drysd\anaconda3\envs\kedro\lib\site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\drysd\anaconda3\envs\kedro\lib\site-packages (from scikit-learn) (3.6.0)

# %%
# %load_ext kedro.ipython
# Out:
# [07/23/25 20:31:23] INFO     Using                                                                  ]8;id=937151;file://C:\Users\drysd\anaconda3\envs\kedro\lib\site-packages\kedro\framework\project\__init__.py\__init__.py]8;;\:]8;id=746449;file://C:\Users\drysd\anaconda3\envs\kedro\lib\site-packages\kedro\framework\project\__init__.py#272\272]8;;\
#                              'C:\Users\drysd\anaconda3\envs\kedro\lib\site-packages\kedro\framework
#                              \project\rich_logging.yml' as logging configuration.
#                     INFO     Registered line magic '%reload_kedro'                                   ]8;id=143860;file://C:\Users\drysd\anaconda3\envs\kedro\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=801866;file://C:\Users\drysd\anaconda3\envs\kedro\lib\site-packages\kedro\ipython\__init__.py#63\63]8;;\
#                     INFO     Registered line magic '%load_node'                                      ]8;id=184770;file://C:\Users\drysd\anaconda3\envs\kedro\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=897755;file://C:\Users\drysd\anaconda3\envs\kedro\lib\site-packages\kedro\ipython\__init__.py#65\65]8;;\
#                     INFO     Resolved project path as: C:\Users\drysd\OneDrive - University of      ]8;id=14776;file://C:\Users\drysd\anaconda3\envs\kedro\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=31582;file://C:\Users\drysd\anaconda3\envs\kedro\lib\site-packages\kedro\ipython\__init__.py#180\180]8;;\
#                              Bath\Documents\September_July_2025\Projects_portfolio\Kedro\spacefligh
#                              ts.
#                              To set a different path, run '%reload_kedro <project_root>'
# [07/23/25 20:31:28] WARNING  C:\Users\drysd\anaconda3\envs\kedro\lib\site-packages\kedro\io\core.py ]8;id=256790;file://C:\Users\drysd\anaconda3\envs\kedro\lib\warnings.py\warnings.py]8;;\:]8;id=753779;file://C:\Users\drysd\anaconda3\envs\kedro\lib\warnings.py#109\109]8;;\
#                              :354: KedroDeprecationWarning: The MatplotlibWriter class has been
#                              renamed to MatplotlibDataset. The MatplotlibWriter name is deprecated
#                              and will be removed in a future release.
#                                init_func(self, *args, **kwargs)
# [07/23/25 20:31:31] INFO     Kedro is sending anonymous usage data with the sole purpose of improving ]8;id=196751;file://C:\Users\drysd\anaconda3\envs\kedro\lib\site-packages\kedro_telemetry\plugin.py\plugin.py]8;;\:]8;id=738006;file://C:\Users\drysd\anaconda3\envs\kedro\lib\site-packages\kedro_telemetry\plugin.py#233\233]8;;\
#                              the product. No personal data or IP addresses are stored on our side. If
#                              you want to opt out, set the `KEDRO_DISABLE_TELEMETRY` or `DO_NOT_TRACK`
#                              environment variables, or create a `.telemetry` file in the current
#                              working directory with the contents `consent: false`. Read more at
#                              https://docs.kedro.org/en/stable/configuration/telemetry.html
# [07/23/25 20:31:32] INFO     Kedro project Spaceflights                                             ]8;id=333875;file://C:\Users\drysd\anaconda3\envs\kedro\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=20977;file://C:\Users\drysd\anaconda3\envs\kedro\lib\site-packages\kedro\ipython\__init__.py#146\146]8;;\
#                     INFO     Defined global variable 'context', 'session', 'catalog' and            ]8;id=467226;file://C:\Users\drysd\anaconda3\envs\kedro\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=984982;file://C:\Users\drysd\anaconda3\envs\kedro\lib\site-packages\kedro\ipython\__init__.py#147\147]8;;\
#                              'pipelines'
# [07/23/25 20:31:33] INFO     Registered line magic 'run_viz'                                        ]8;id=958320;file://C:\Users\drysd\anaconda3\envs\kedro\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=121343;file://C:\Users\drysd\anaconda3\envs\kedro\lib\site-packages\kedro\ipython\__init__.py#153\153]8;;\

# %%
df = catalog.load('model_input_table')
df.head()
# Out:
# [07/23/25 20:32:26] INFO     Loading data from model_input_table (ParquetDataset)...            ]8;id=860708;file://C:\Users\drysd\anaconda3\envs\kedro\lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=972916;file://C:\Users\drysd\anaconda3\envs\kedro\lib\site-packages\kedro\io\data_catalog.py#403\403]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#         shuttle_location shuttle_type engine_type       engine_vendor  \
# 0  Sao Tome and Principe      Type V5      Plasma  ThetaBase Services
# 1      Wallis and Futuna      Type V2      Plasma  ThetaBase Services
# 2                   Niue      Type F5     Quantum  ThetaBase Services
# 3                  Malta      Type V2     Quantum  ThetaBase Services
# 4                  Malta      Type V2      Plasma  ThetaBase Services
#
#    engines  passenger_capacity cancellation_policy  crew  d_check_complete  \
# 0      2.0                   4            moderate   2.0             False
# 1      3.0                   5            moderate   3.0             False
# 2      1.0                   2              strict   1.0              True
# 3      1.0                   2            moderate   1.0             False
# 4      5.0                  10              strict   5.0             False
#
#    moon_clearance_complete  ...  review_scores_crew  review_scores_location  \
# 0                    False  ...                 9.0                     9.0
# 1                    False  ...                10.0                    10.0
# 2                    False  ...                10.0                    10.0
# 3                    False  ...                10.0                     9.0
# 4                    False  ...                10.0                     9.0
#
#    review_scores_price  number_of_reviews  reviews_per_month     id  \
# 0                  9.0                 26               0.77  32413
# 1                  9.0                 61               0.62  14122
# 2                 10.0                467               4.66  47761
# 3                  9.0                318               3.22  26648
# 4                 10.0                 22               0.29  26648
#
#    company_rating  company_location  total_fleet_count  iata_approved
# 0             1.0     Faroe Islands                1.0          False
# 1             1.0             Malta                1.0           True
# 2             1.0              Niue                2.0          False
# 3             1.0              Niue                2.0           True
# 4             1.0              Niue                2.0           True
#
# [5 rows x 27 columns]

# %%
import sklearn

# %%
from sklearn.model_selection import train_test_split

# %%
features = [
     'engines',
    'passenger_capacity',
    'crew',
    'd_check_complete',
     'moon_clearance_complete',
    'iata_approved',
    'company_rating',
    'review_scores_rating'
]

# %%
X = df[features]
Y = df['price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.predict(X_test)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# array([1868.94905826, 2695.0578746 , 1648.90810362, ..., 1457.64307964,
#        2694.8042566 , 1417.77096189], shape=(1206,))

# %%
from sklearn.metrics import r2_score

# %%
y_pred = model.predict(X_test)

# %%
r2_score(y_test, y_pred)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 0.348220741580226
