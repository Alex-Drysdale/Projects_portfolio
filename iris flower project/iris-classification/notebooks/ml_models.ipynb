# %% [markdown]
# # Testing and verifying different ML models

# %%
# %load_ext kedro.ipython
# %reload_kedro
# Out:
# [07/30/25 22:06:37] INFO     Using                                                                  ]8;id=925046;file://c:\Users\drysd\anaconda3\envs\kedro\lib\site-packages\kedro\framework\project\__init__.py\__init__.py]8;;\:]8;id=72066;file://c:\Users\drysd\anaconda3\envs\kedro\lib\site-packages\kedro\framework\project\__init__.py#272\272]8;;\
#                              'c:\Users\drysd\anaconda3\envs\kedro\lib\site-packages\kedro\framework
#                              \project\rich_logging.yml' as logging configuration.
#                     INFO     Registered line magic '%reload_kedro'                                   ]8;id=827977;file://c:\Users\drysd\anaconda3\envs\kedro\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=165773;file://c:\Users\drysd\anaconda3\envs\kedro\lib\site-packages\kedro\ipython\__init__.py#63\63]8;;\
#                     INFO     Registered line magic '%load_node'                                      ]8;id=676382;file://c:\Users\drysd\anaconda3\envs\kedro\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=850051;file://c:\Users\drysd\anaconda3\envs\kedro\lib\site-packages\kedro\ipython\__init__.py#65\65]8;;\
#                     INFO     Resolved project path as: c:\Users\drysd\OneDrive - University of      ]8;id=150191;file://c:\Users\drysd\anaconda3\envs\kedro\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=810997;file://c:\Users\drysd\anaconda3\envs\kedro\lib\site-packages\kedro\ipython\__init__.py#180\180]8;;\
#                              Bath\Documents\September_July_2025\Projects_portfolio\iris flower
#                              project\iris-classification.
#                              To set a different path, run '%reload_kedro <project_root>'
# [07/30/25 22:06:38] INFO     Kedro is sending anonymous usage data with the sole purpose of improving ]8;id=97505;file://c:\Users\drysd\anaconda3\envs\kedro\lib\site-packages\kedro_telemetry\plugin.py\plugin.py]8;;\:]8;id=234680;file://c:\Users\drysd\anaconda3\envs\kedro\lib\site-packages\kedro_telemetry\plugin.py#233\233]8;;\
#                              the product. No personal data or IP addresses are stored on our side. If
#                              you want to opt out, set the `KEDRO_DISABLE_TELEMETRY` or `DO_NOT_TRACK`
#                              environment variables, or create a `.telemetry` file in the current
#                              working directory with the contents `consent: false`. Read more at
#                              https://docs.kedro.org/en/stable/configuration/telemetry.html
# [07/30/25 22:06:40] INFO     Kedro project iris_classification                                      ]8;id=513608;file://c:\Users\drysd\anaconda3\envs\kedro\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=367461;file://c:\Users\drysd\anaconda3\envs\kedro\lib\site-packages\kedro\ipython\__init__.py#146\146]8;;\
#                     INFO     Defined global variable 'context', 'session', 'catalog' and            ]8;id=203707;file://c:\Users\drysd\anaconda3\envs\kedro\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=209954;file://c:\Users\drysd\anaconda3\envs\kedro\lib\site-packages\kedro\ipython\__init__.py#147\147]8;;\
#                              'pipelines'
#                     INFO     Registered line magic 'run_viz'                                        ]8;id=24953;file://c:\Users\drysd\anaconda3\envs\kedro\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=217409;file://c:\Users\drysd\anaconda3\envs\kedro\lib\site-packages\kedro\ipython\__init__.py#153\153]8;;\
#                     INFO     Resolved project path as: C:\Users\drysd\OneDrive - University of      ]8;id=246486;file://c:\Users\drysd\anaconda3\envs\kedro\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=438815;file://c:\Users\drysd\anaconda3\envs\kedro\lib\site-packages\kedro\ipython\__init__.py#180\180]8;;\
#                              Bath\Documents\September_July_2025\Projects_portfolio\iris flower
#                              project\iris-classification.
#                              To set a different path, run '%reload_kedro <project_root>'
# [07/30/25 22:06:41] INFO     Kedro is sending anonymous usage data with the sole purpose of improving ]8;id=422792;file://c:\Users\drysd\anaconda3\envs\kedro\lib\site-packages\kedro_telemetry\plugin.py\plugin.py]8;;\:]8;id=146685;file://c:\Users\drysd\anaconda3\envs\kedro\lib\site-packages\kedro_telemetry\plugin.py#233\233]8;;\
#                              the product. No personal data or IP addresses are stored on our side. If
#                              you want to opt out, set the `KEDRO_DISABLE_TELEMETRY` or `DO_NOT_TRACK`
#                              environment variables, or create a `.telemetry` file in the current
#                              working directory with the contents `consent: false`. Read more at
#                              https://docs.kedro.org/en/stable/configuration/telemetry.html
#                     INFO     Kedro project iris_classification                                      ]8;id=836066;file://c:\Users\drysd\anaconda3\envs\kedro\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=951211;file://c:\Users\drysd\anaconda3\envs\kedro\lib\site-packages\kedro\ipython\__init__.py#146\146]8;;\
#                     INFO     Defined global variable 'context', 'session', 'catalog' and            ]8;id=413544;file://c:\Users\drysd\anaconda3\envs\kedro\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=999788;file://c:\Users\drysd\anaconda3\envs\kedro\lib\site-packages\kedro\ipython\__init__.py#147\147]8;;\
#                              'pipelines'
#                     INFO     Registered line magic 'run_viz'                                        ]8;id=620678;file://c:\Users\drysd\anaconda3\envs\kedro\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=149922;file://c:\Users\drysd\anaconda3\envs\kedro\lib\site-packages\kedro\ipython\__init__.py#153\153]8;;\

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import accuracy_score

# %%
df = catalog.load('iris_data')
df.head()
# Out:
# [07/30/25 22:06:47] INFO     Loading data from iris_data (CSVDataset)...                        ]8;id=775133;file://c:\Users\drysd\anaconda3\envs\kedro\lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=139049;file://c:\Users\drysd\anaconda3\envs\kedro\lib\site-packages\kedro\io\data_catalog.py#403\403]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
x = df.drop('species', axis=1)
y = df['species']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state=5)

# %% [markdown]
# ## KNeighbours Classifier
# ...
